# %%
# Import library
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import keras
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import preprocessing


from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix


# Load dataset
dataset = pd.read_csv("heart.csv")

#Read target column as y
y=dataset.target

#Take all of column and drop target column as x
x=dataset.drop('target',axis=1)


min_max_scaler = preprocessing.MinMaxScaler() #Normalizing data to value from 0-1
x_scaled = min_max_scaler.fit_transform(x)

# Split data into training and test 
X_train,X_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.35,random_state=4)



# Define the keras model
model = Sequential()

# Input layer consists 13 neuron
# Hidden layer consists 10 neuron
# Output layer consists 1 neuron

model.add(Dense(10, input_dim=13, activation='sigmoid'))
#model.add(Dense(5, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))


# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#trained = model.fit(X_train, y_train, epochs=1500, batch_size=4, validation_data=(X_test, y_test))
trained = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

#Plotting accuracy and loss chart
plt.plot(trained.history['accuracy'] )
plt.plot(trained.history['val_accuracy'])

plt.title('Accuracy')
plt.ylabel('Value')
plt.xlabel('epoch')
plt.legend(['Training Accuracy' , 'Test Accuracy'], loc='lower right')
plt.show()

plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])

plt.title('Loss')
plt.ylabel('Value')
plt.xlabel('epoch')
plt.legend(['Training Loss' , 'Test Loss'], loc='upper right')
plt.show()


#Tak faham coding ni tapi aku rembat lol
#classifier_tree = DecisionTreeClassifier()
#y_predict = classifier_tree.fit(X_train, y_train).predict(X_test)
#print(classification_report(y_test, y_predict))
#print(confusion_matrix(y_test, y_predict))
# Out:
# Epoch 1/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.9334 - accuracy: 0.5203 - val_loss: 0.9158 - val_accuracy: 0.5014
# Epoch 2/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.8547 - accuracy: 0.5203 - val_loss: 0.8388 - val_accuracy: 0.5014
# Epoch 3/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7923 - accuracy: 0.5203 - val_loss: 0.7834 - val_accuracy: 0.5014
# Epoch 4/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7490 - accuracy: 0.5203 - val_loss: 0.7429 - val_accuracy: 0.5014
# Epoch 5/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7174 - accuracy: 0.5203 - val_loss: 0.7166 - val_accuracy: 0.5014
# Epoch 6/50
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6967 - accuracy: 0.5203 - val_loss: 0.6962 - val_accuracy: 0.5014
# Epoch 7/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6817 - accuracy: 0.5203 - val_loss: 0.6816 - val_accuracy: 0.5014
# Epoch 8/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6707 - accuracy: 0.5203 - val_loss: 0.6706 - val_accuracy: 0.5014
# Epoch 9/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6627 - accuracy: 0.5338 - val_loss: 0.6617 - val_accuracy: 0.5125
# Epoch 10/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6558 - accuracy: 0.5474 - val_loss: 0.6544 - val_accuracy: 0.5933
# Epoch 11/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6498 - accuracy: 0.6211 - val_loss: 0.6480 - val_accuracy: 0.6797
# Epoch 12/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6442 - accuracy: 0.6662 - val_loss: 0.6425 - val_accuracy: 0.7075
# Epoch 13/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6387 - accuracy: 0.6902 - val_loss: 0.6368 - val_accuracy: 0.7159
# Epoch 14/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6336 - accuracy: 0.6992 - val_loss: 0.6311 - val_accuracy: 0.7214
# Epoch 15/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6285 - accuracy: 0.7098 - val_loss: 0.6254 - val_accuracy: 0.7493
# Epoch 16/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6233 - accuracy: 0.7173 - val_loss: 0.6203 - val_accuracy: 0.7521
# Epoch 17/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6181 - accuracy: 0.7338 - val_loss: 0.6146 - val_accuracy: 0.7827
# Epoch 18/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.