# %%
# Import library
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import keras
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import preprocessing


from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix


# Load dataset
dataset = pd.read_csv("heart.csv")

#Read target column as y
y=dataset.target

#Take all of column and drop target column as x
x=dataset.drop('target',axis=1)


min_max_scaler = preprocessing.MinMaxScaler() #Normalizing data to value from 0-1
x_scaled = min_max_scaler.fit_transform(x)

# Split data into training and test 
X_train,X_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=4)



# Define the keras model
model = Sequential()

#First hidden layer with 10 neuron, 13 input (using sigmoid activation function)
model.add(Dense(10, input_shape=(13,), activation='sigmoid'))

#Second hidden layer with 10 neuron (using sigmoid activation function)
model.add(Dense(10, activation='sigmoid'))

#Output layer with 1 neuron (using sigmoid activation function)
model.add(Dense(1, activation='sigmoid'))


# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

trained = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

#evaluate the keras model
_,accuracy = model.evaluate(X_train, y_train)

print('Accuracy: %.2f' % (accuracy*100))

#Plotting accuracy and loss chart
plt.plot(trained.history['accuracy'] )
plt.plot(trained.history['val_accuracy'])

plt.title('Accuracy')
plt.ylabel('Value')
plt.xlabel('epoch')
plt.legend(['Training Accuracy' , 'Test Accuracy'], loc='lower right')
plt.show()

plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])

plt.title('Loss')
plt.ylabel('Value')
plt.xlabel('epoch')
plt.legend(['Training Loss' , 'Test Loss'], loc='upper right')
plt.show()


#Tak faham coding ni tapi aku rembat lol
classifier_tree = DecisionTreeClassifier()
y_predict = classifier_tree.fit(X_train, y_train).predict(X_test)
print(classification_report(y_test, y_predict))
print(confusion_matrix(y_test, y_predict))
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6934 - accuracy: 0.4972 - val_loss: 0.6922 - val_accuracy: 0.5390
# Epoch 2/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6907 - accuracy: 0.5489 - val_loss: 0.6895 - val_accuracy: 0.5325
# Epoch 3/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6888 - accuracy: 0.5223 - val_loss: 0.6873 - val_accuracy: 0.5260
# Epoch 4/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6872 - accuracy: 0.5112 - val_loss: 0.6849 - val_accuracy: 0.5195
# Epoch 5/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6844 - accuracy: 0.5656 - val_loss: 0.6825 - val_accuracy: 0.6591
# Epoch 6/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6817 - accuracy: 0.5461 - val_loss: 0.6791 - val_accuracy: 0.5812
# Epoch 7/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6780 - accuracy: 0.6634 - val_loss: 0.6756 - val_accuracy: 0.7305
# Epoch 8/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6741 - accuracy: 0.7039 - val_loss: 0.6711 - val_accuracy: 0.7338
# Epoch 9/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6700 - accuracy: 0.7542 - val_loss: 0.6664 - val_accuracy: 0.7825
# Epoch 10/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6638 - accuracy: 0.7514 - val_loss: 0.6603 - val_accuracy: 0.7857
# Epoch 11/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6577 - accuracy: 0.7486 - val_loss: 0.6532 - val_accuracy: 0.7857
# Epoch 12/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6508 - accuracy: 0.7458 - val_loss: 0.6459 - val_accuracy: 0.7922
# Epoch 13/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6436 - accuracy: 0.7598 - val_loss: 0.6375 - val_accuracy: 0.7987
# Epoch 14/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6350 - accuracy: 0.7640 - val_loss: 0.6281 - val_accuracy: 0.8019
# Epoch 15/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6255 - accuracy: 0.7640 - val_loss: 0.6182 - val_accuracy: 0.7922
# Epoch 16/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6155 - accuracy: 0.7682 - val_loss: 0.6076 - val_accuracy: 0.7922
# Epoch 17/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6048 - accuracy: 0.7765 - val_loss: 0.5961 - val_accuracy: 0.7955
# Epoch 18/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5936 - accuracy: 0.7737 - val_loss: 0.5838 - val_accuracy: 0.8052
# Epoch 19/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5813 - accuracy: 0.7821 - val_loss: 0.5706 - val_accuracy: 0.8052
# Epoch 20/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5687 - accuracy: 0.7793 - val_loss: 0.5567 - val_accuracy: 0.8084
# Epoch 21/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5562 - accuracy: 0.7807 - val_loss: 0.5434 - val_accuracy: 0.8149
# Epoch 22/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5433 - accuracy: 0.7835 - val_loss: 0.5292 - val_accuracy: 0.8182
# Epoch 23/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5309 - accuracy: 0.7905 - val_loss: 0.5176 - val_accuracy: 0.8182
# Epoch 24/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5184 - accuracy: 0.7891 - val_loss: 0.5034 - val_accuracy: 0.8182
# Epoch 25/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5063 - accuracy: 0.7933 - val_loss: 0.4909 - val_accuracy: 0.8182
# Epoch 26/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4959 - accuracy: 0.8003 - val_loss: 0.4794 - val_accuracy: 0.8182
# Epoch 27/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4855 - accuracy: 0.7919 - val_loss: 0.4682 - val_accuracy: 0.8182
# Epoch 28/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4750 - accuracy: 0.7933 - val_loss: 0.4584 - val_accuracy: 0.8312
# Epoch 29/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4666 - accuracy: 0.8087 - val_loss: 0.4509 - val_accuracy: 0.8247
# Epoch 30/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4588 - accuracy: 0.8059 - val_loss: 0.4401 - val_accuracy: 0.8312
# Epoch 31/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4506 - accuracy: 0.8101 - val_loss: 0.4340 - val_accuracy: 0.8279
# Epoch 32/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4439 - accuracy: 0.8115 - val_loss: 0.4271 - val_accuracy: 0.8312
# Epoch 33/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4377 - accuracy: 0.8142 - val_loss: 0.4197 - val_accuracy: 0.8377
# Epoch 34/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4323 - accuracy: 0.8170 - val_loss: 0.4139 - val_accuracy: 0.8312
# Epoch 35/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4280 - accuracy: 0.8184 - val_loss: 0.4086 - val_accuracy: 0.8312
# Epoch 36/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.8198 - val_loss: 0.4052 - val_accuracy: 0.8344
# Epoch 37/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4188 - accuracy: 0.8212 - val_loss: 0.3995 - val_accuracy: 0.8312
# Epoch 38/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4152 - accuracy: 0.8282 - val_loss: 0.3979 - val_accuracy: 0.8344
# Epoch 39/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8240 - val_loss: 0.3934 - val_accuracy: 0.8344
# Epoch 40/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4080 - accuracy: 0.8254 - val_loss: 0.3911 - val_accuracy: 0.8344
# Epoch 41/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4054 - accuracy: 0.8212 - val_loss: 0.3871 - val_accuracy: 0.8344
# Epoch 42/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8254 - val_loss: 0.3858 - val_accuracy: 0.8377
# Epoch 43/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8240 - val_loss: 0.3824 - val_accuracy: 0.8344
# Epoch 44/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8198 - val_loss: 0.3791 - val_accuracy: 0.8344
# Epoch 45/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3957 - accuracy: 0.8226 - val_loss: 0.3783 - val_accuracy: 0.8409
# Epoch 46/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3937 - accuracy: 0.8338 - val_loss: 0.3761 - val_accuracy: 0.8409
# Epoch 47/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8338 - val_loss: 0.3740 - val_accuracy: 0.8442
# Epoch 48/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8394 - val_loss: 0.3737 - val_accuracy: 0.8506
# Epoch 49/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3888 - accuracy: 0.8422 - val_loss: 0.3728 - val_accuracy: 0.8506
# Epoch 50/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3874 - accuracy: 0.8436 - val_loss: 0.3717 - val_accuracy: 0.8506
# 23/23 [==============================] - 0s 455us/step - loss: 0.3862 - accuracy: 0.8436
# Accuracy: 84.36
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       148
#            1       1.00      0.96      0.98       160
#
#     accuracy                           0.98       308
#    macro avg       0.98      0.98      0.98       308
# weighted avg       0.98      0.98      0.98       308
#
# [[148   0]
#  [  6 154]]

# %%
train_score = model.evaluate(X_train, y_train, verbose=0)

print('Train loss:', train_score[0])
print('Train accuracy:', train_score[1])

test_score = model.evaluate(X_test, y_test, verbose=0)
print('Train loss:', test_score[0])
print('Train accuracy:', test_score[1])
# Out:
# Train loss: 0.26950278878211975
# Train accuracy: 0.8766917586326599
# Train loss: 0.27077561616897583
# Train accuracy: 0.8586309552192688

# %%
# Import library
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import keras
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import preprocessing


from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix


# Load dataset
dataset = pd.read_csv("heart.csv")

#Read target column as y
y=dataset.target

#Take all of column and drop target column as x
x=dataset.drop('target',axis=1)


min_max_scaler = preprocessing.MinMaxScaler() #Normalizing data to value from 0-1
x_scaled = min_max_scaler.fit_transform(x)

# Split data into training and test 
X_train,X_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.35,random_state=4)



# Define the keras model
model = Sequential()

# Input layer consists 13 neuron
# Hidden layer consists 10 neuron
# Output layer consists 1 neuron

model.add(Dense(10, input_dim=13, activation='sigmoid'))
#model.add(Dense(5, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))


# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#trained = model.fit(X_train, y_train, epochs=1500, batch_size=4, validation_data=(X_test, y_test))
model.save('model.h5')
trained = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

#Plotting accuracy and loss chart
plt.plot(trained.history['accuracy'] )
plt.plot(trained.history['val_accuracy'])

plt.title('Accuracy')
plt.ylabel('Value')
plt.xlabel('epoch')
plt.legend(['Training Accuracy' , 'Test Accuracy'], loc='lower right')
plt.show()

plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])

plt.title('Loss')
plt.ylabel('Value')
plt.xlabel('epoch')
plt.legend(['Training Loss' , 'Test Loss'], loc='upper right')
plt.show()


#Tak faham coding ni tapi aku rembat lol
#classifier_tree = DecisionTreeClassifier()
#y_predict = classifier_tree.fit(X_train, y_train).predict(X_test)
#print(classification_report(y_test, y_predict))
#print(confusion_matrix(y_test, y_predict))
# Out:
# Epoch 1/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.6976 - accuracy: 0.4662 - val_loss: 0.6889 - val_accuracy: 0.5571
# Epoch 2/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6901 - accuracy: 0.5323 - val_loss: 0.6823 - val_accuracy: 0.6100
# Epoch 3/50
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5985 - val_loss: 0.6754 - val_accuracy: 0.6825
# Epoch 4/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6763 - accuracy: 0.6647 - val_loss: 0.6690 - val_accuracy: 0.7214
# Epoch 5/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6703 - accuracy: 0.6947 - val_loss: 0.6627 - val_accuracy: 0.7409
# Epoch 6/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6634 - accuracy: 0.7293 - val_loss: 0.6556 - val_accuracy: 0.7744
# Epoch 7/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6569 - accuracy: 0.7338 - val_loss: 0.6489 - val_accuracy: 0.7883
# Epoch 8/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6502 - accuracy: 0.7474 - val_loss: 0.6424 - val_accuracy: 0.8050
# Epoch 9/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6438 - accuracy: 0.7549 - val_loss: 0.6356 - val_accuracy: 0.8106
# Epoch 10/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6369 - accuracy: 0.7669 - val_loss: 0.6286 - val_accuracy: 0.8106
# Epoch 11/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6299 - accuracy: 0.7639 - val_loss: 0.6216 - val_accuracy: 0.8022
# Epoch 12/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6231 - accuracy: 0.7624 - val_loss: 0.6146 - val_accuracy: 0.8106
# Epoch 13/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6163 - accuracy: 0.7744 - val_loss: 0.6073 - val_accuracy: 0.8078
# Epoch 14/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6092 - accuracy: 0.7774 - val_loss: 0.6002 - val_accuracy: 0.8078
# Epoch 15/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6022 - accuracy: 0.7805 - val_loss: 0.5927 - val_accuracy: 0.8162
# Epoch 16/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5952 - accuracy: 0.7759 - val_loss: 0.5856 - val_accuracy: 0.8134
# Epoch 17/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5877 - accuracy: 0.7774 - val_loss: 0.5780 - val_accuracy: 0.8217
# Epoch 18/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5804 - accuracy: 0.7835 - val_loss: 0.5707 - val_accuracy: 0.8162
# Epoch 19/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5731 - accuracy: 0.7820 - val_loss: 0.5632 - val_accuracy: 0.8217
# Epoch 20/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5659 - accuracy: 0.7820 - val_loss: 0.5557 - val_accuracy: 0.8134
# Epoch 21/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5585 - accuracy: 0.7805 - val_loss: 0.5486 - val_accuracy: 0.8134
# Epoch 22/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5519 - accuracy: 0.7774 - val_loss: 0.5413 - val_accuracy: 0.8106
# Epoch 23/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5445 - accuracy: 0.7789 - val_loss: 0.5339 - val_accuracy: 0.8134
# Epoch 24/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5375 - accuracy: 0.7789 - val_loss: 0.5267 - val_accuracy: 0.8134
# Epoch 25/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.7789 - val_loss: 0.5199 - val_accuracy: 0.8134
# Epoch 26/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5239 - accuracy: 0.7820 - val_loss: 0.5131 - val_accuracy: 0.8189
# Epoch 27/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5177 - accuracy: 0.7835 - val_loss: 0.5067 - val_accuracy: 0.8162
# Epoch 28/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5112 - accuracy: 0.7850 - val_loss: 0.5002 - val_accuracy: 0.8217
# Epoch 29/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5051 - accuracy: 0.7865 - val_loss: 0.4941 - val_accuracy: 0.8217
# Epoch 30/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4991 - accuracy: 0.7895 - val_loss: 0.4881 - val_accuracy: 0.8217
# Epoch 31/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4933 - accuracy: 0.7910 - val_loss: 0.4824 - val_accuracy: 0.8273
# Epoch 32/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4880 - accuracy: 0.7970 - val_loss: 0.4768 - val_accuracy: 0.8273
# Epoch 33/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4828 - accuracy: 0.7985 - val_loss: 0.4716 - val_accuracy: 0.8273
# Epoch 34/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4774 - accuracy: 0.7970 - val_loss: 0.4666 - val_accuracy: 0.8273
# Epoch 35/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.8030 - val_loss: 0.4619 - val_accuracy: 0.8301
# Epoch 36/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4681 - accuracy: 0.7985 - val_loss: 0.4570 - val_accuracy: 0.8273
# Epoch 37/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4639 - accuracy: 0.8060 - val_loss: 0.4527 - val_accuracy: 0.8301
# Epoch 38/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4592 - accuracy: 0.8060 - val_loss: 0.4485 - val_accuracy: 0.8301
# Epoch 39/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4551 - accuracy: 0.8060 - val_loss: 0.4445 - val_accuracy: 0.8301
# Epoch 40/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4515 - accuracy: 0.8060 - val_loss: 0.4408 - val_accuracy: 0.8301
# Epoch 41/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4478 - accuracy: 0.8105 - val_loss: 0.4369 - val_accuracy: 0.8301
# Epoch 42/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4440 - accuracy: 0.8135 - val_loss: 0.4336 - val_accuracy: 0.8301
# Epoch 43/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4406 - accuracy: 0.8090 - val_loss: 0.4305 - val_accuracy: 0.8357
# Epoch 44/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4374 - accuracy: 0.8195 - val_loss: 0.4273 - val_accuracy: 0.8357
# Epoch 45/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4343 - accuracy: 0.8165 - val_loss: 0.4241 - val_accuracy: 0.8329
# Epoch 46/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4313 - accuracy: 0.8195 - val_loss: 0.4215 - val_accuracy: 0.8357
# Epoch 47/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4284 - accuracy: 0.8241 - val_loss: 0.4186 - val_accuracy: 0.8357
# Epoch 48/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4257 - accuracy: 0.8241 - val_loss: 0.4162 - val_accuracy: 0.8357
# Epoch 49/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4235 - accuracy: 0.8226 - val_loss: 0.4138 - val_accuracy: 0.8329
# Epoch 50/50
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4207 - accuracy: 0.8241 - val_loss: 0.4112 - val_accuracy: 0.8357

# %%
y_pred = model.predict(X_test)
y_test = np.array(y_test)

hold_test = 0
true_pred = 0
swap_pred = []
false_pred = 0


for i in range(308):
    if y_pred[i] <= 0.5:
        swap_pred.append(0)
    else : 
        swap_pred.append(1)
        

for i in range(308) :
    
    if swap_pred[i] == y_test[i] :
        print("Predicted Value : " , swap_pred[i] , " Actual Value : " , y_test[i] , " [True]")
        true_pred = true_pred + 1
    else : 
        print("Predicted Value : " , swap_pred[i] , " Actual Value : " , y_test[i] , " [False]")
        false_pred = false_pred + 1
        
print("Total of correct prediction : " , true_pred)
print("Total of false prediction : " , false_pred)
print("Accuracy of prediction : " , true_pred/308 * 100)
     

#Tak faham coding ni tapi aku rembat lol
classifier_tree = DecisionTreeClassifier()
y_predict = classifier_tree.fit(X_train, y_train).predict(X_test)
print(classification_report(y_test, y_predict))
print(confusion_matrix(y_test, y_predict))
# Out:
# 12/12 [==============================] - 0s 455us/step
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  1  [True]
# Predicted Value :  1  Actual Value :  0  [False]
# Predicted Value :  0  Actual Value :  1  [False]
# Predicted Value :  0  Actual Value :  0  [True]
# Predicted Value :  0  Actual Value :  0  [True]
# Total of correct prediction :  262
# Total of false prediction :  46
# Accuracy of prediction :  85.06493506493507
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       179
#            1       0.98      0.98      0.98       180
#
#     accuracy                           0.98       359
#    macro avg       0.98      0.98      0.98       359
# weighted avg       0.98      0.98      0.98       359
#
# [[176   3]
#  [  3 177]]
